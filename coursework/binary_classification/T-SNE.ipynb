# %%
from sklearn import datasets
from matplotlib import pyplot as plt

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# T-SNE 
from sklearn.manifold import TSNE

# %% [markdown]
# # Divided into two sections: total and sampled
#
# #### Total: The data is converted to binary classification across all Y targets
#
# #### Sampled: Similar to 'total' but there is a minor difference. The data is evenly distributed. For example, if 'dep_score depression=0' counts 100 and 'dep_score depression=1' counts 60 then the sampled data looks like: 'dep_score depression=0' counts 60 and 'dep_score depression=1' counts 60. The number of 'dep_score depression=0' changed from 100 to 60 so that the number of data for each category(depression=0 or 1) is even.
#
#
# - Y targets: dep_score, dep_thoughts, has_dep_diag, prim_diag, secd_diag
# - 0: not depressed
# - 1: depressed

# %% [markdown]
# # Total dep score

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(15, 10))

# dep score
total_dep_score = pd.read_csv('../data/0&1/total_dep_score.csv')

X = total_dep_score.copy()
del X['dep_score']

target = total_dep_score['dep_score']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax1.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)

# dep thoughts 
total_dep_thoughts = pd.read_csv('../data/0&1/total_dep_thoughts.csv')

X = total_dep_thoughts.copy()
del X['dep_thoughts']

target = total_dep_thoughts['dep_thoughts']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax2.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)

# has_dep_diag
total_has_dep_diag = pd.read_csv('../data/0&1/total_has_dep_diag.csv')

X = total_has_dep_diag.copy()
del X['has_dep_diag']

target = total_has_dep_diag['has_dep_diag']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax3.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)

# prim_diag 
total_prim_diag = pd.read_csv('../data/0&1/total_prim_diag.csv')

X = total_prim_diag.copy()
del X['prim_diag']

target = total_prim_diag['prim_diag']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax4.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)

# secd_diag
total_secd_diag = pd.read_csv('../data/0&1/total_secd_diag.csv')

X = total_secd_diag.copy()
del X['secd_diag']

target = total_secd_diag['secd_diag']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax5.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)
    
# panic_score
total_panic_score = pd.read_csv('../data/0&1/total_panic_score.csv')

X = total_panic_score.copy()
del X['panic_score']

target = total_panic_score['panic_score']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax6.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)
    
ax6.legend(loc='upper center', bbox_to_anchor=(-0.7, -0.15),
          fancybox=True, shadow=True, ncol=2)


ax1.set_title('dep_score')
ax2.set_title('dep_thoughts')
ax3.set_title('has_dep_diag')
ax4.set_title('prim_diag')
ax5.set_title('secd_diag')
ax6.set_title('panic_score')

plt.show()

# %% [markdown]
# # Sampled dep score

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(15, 10))


# dep score
sampled_dep_score = pd.read_csv('../data/0&1/sampled_dep_score.csv')

X = sampled_dep_score.copy()
del X['dep_score']

target = sampled_dep_score['dep_score']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax1.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)

    
# dep thoughts
sampled_dep_thoughts = pd.read_csv('../data/0&1/sampled_dep_thoughts.csv')

X = sampled_dep_thoughts.copy()
del X['dep_thoughts']

target = sampled_dep_thoughts['dep_thoughts']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax2.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)

    
# has dep diag 
sampled_has_dep_diag = pd.read_csv('../data/0&1/sampled_has_dep_diag.csv')

X = sampled_has_dep_diag.copy()
del X['has_dep_diag']

target = sampled_has_dep_diag['has_dep_diag']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax3.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)

    
# prim diag 
sampled_prim_diag = pd.read_csv('../data/0&1/sampled_prim_diag.csv')

X = sampled_prim_diag.copy()
del X['prim_diag']

target = sampled_prim_diag['prim_diag']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax4.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)


# secd diag 
sampled_secd_diag = pd.read_csv('../data/0&1/sampled_secd_diag.csv')

X = sampled_secd_diag.copy()
del X['secd_diag']

target = sampled_secd_diag['secd_diag']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax5.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)

# panic_score
sampled_panic_score = pd.read_csv('../data/0&1/sampled_panic_score.csv')

X = sampled_panic_score.copy()
del X['panic_score']

target = sampled_panic_score['panic_score']

tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(X)
target_ids = range(2)

plt.figure(figsize=(6, 6))
colors = 'r', 'g'
for i, c, label in zip(target_ids, colors, ['not depressed', 'depressed']):
    ax6.scatter(X_tsne[target == i, 0], X_tsne[target == i, 1], c=c, label=label, alpha=0.2)
    
ax6.legend(loc='upper center', bbox_to_anchor=(-0.7, -0.15),
          fancybox=True, shadow=True, ncol=2)

ax1.set_title('dep_score')
ax2.set_title('dep_thoughts')
ax3.set_title('has_dep_diag')
ax4.set_title('prim_diag')
ax5.set_title('secd_diag')
ax6.set_title('panic_score')

plt.show()
