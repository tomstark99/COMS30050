# %%
import seaborn as sns
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('all_B_A_data.csv')

# %%
data
# Out:
#     comp_house  comp_int_bed_16  comp_noint_bed_16  comp_week  comp_wend  \
# 0            1                1                  1          2          2
# 1            1                1                  1          3          3
# 2            1                1                  1          1          1
# 3            1                1                  1          2          1
# 4            1                1                  1          2          3
# 5            1                1                  1          1          1
# 6            1                1                  1          2          2
# 7            1                1                  1          2          2
# 8            1                1                  1          3          3
# 9            1                1                  1          3          3
# 10           1                1                  1          3          3
# 11           1                1                  1          3          2
# ...

# %%
fig, ax = plt.subplots(figsize=(7, 7))

X_ds = data.copy()
ds = X_ds.corr()
sns.heatmap(ds, annot=True)

ax.set_title('dep_score', fontsize=20)
# Out:
# Text(0.5, 1.0, 'dep_score')
