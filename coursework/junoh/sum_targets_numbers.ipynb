# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
filename = '../data/0&1/sum_targets_with_panic.csv'
data = pd.read_csv(filename)

# %%
data
# Out:
#       comp_week  comp_wend  text_week  text_wend  tv_week  tv_wend  dep_score  \
# 0             1          2          1          1        1        2        0.0
# 1             2          2          3          3        1        2        1.0
# 2             1          0          1          2        1        1        1.0
# 3             2          3          3          3        2        3        1.0
# 4             2          3          1          1        2        1        1.0
# ...         ...        ...        ...        ...      ...      ...        ...
# 1249          2          2          2          2        2        1        0.0
# 1250          3          3          1          1        1        2        0.0
# 1251          3          0          2          2        2        2        0.0
# 1252          2          3          1          1        1        2        0.0
# 1253          2          3          1          1        1        2        1.0
#
# ...

# %%
data_numbers = {}

data_numbers['total'] = dict(sorted(data['total'].value_counts().items()))

zero = { 0.0: 0 }

zero.update(data_numbers['total'])

# %%
data_numbers = zero

# %%
x = np.arange(len(data_numbers))
values = [data_numbers[i] for i in data_numbers]

plt.bar(x, values)
plt.xticks(x, data_numbers.keys())
plt.title("The number of 'total' values")
plt.show()
